# %%
import pandas as pd
data=pd.read_csv("Superstore.csv", encoding='latin1')

# %%
data.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
data.shape
# Out:
# (9994, 21)

# %%
data.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
data.isna().sum()
# Out:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.describe()
# Out:
#             Row ID   Postal Code         Sales     Quantity     Discount  \
# count  9994.000000   9994.000000   9994.000000  9994.000000  9994.000000
# mean   4997.500000  55190.379428    229.858001     3.789574     0.156203
# std    2885.163629  32063.693350    623.245101     2.225110     0.206452
# min       1.000000   1040.000000      0.444000     1.000000     0.000000
# 25%    2499.250000  23223.000000     17.280000     2.000000     0.000000
# 50%    4997.500000  56430.500000     54.490000     3.000000     0.200000
# 75%    7495.750000  90008.000000    209.940000     5.000000     0.200000
# max    9994.000000  99301.000000  22638.480000    14.000000     0.800000
#
#             Profit
# count  9994.000000
# mean     28.656896
# std     234.260108
# min   -6599.978000
# 25%       1.728750
# 50%       8.666500
# 75%      29.364000
# max    8399.976000

# %%
plt.subplot(1,2,1)
sns.boxplot(data=data,y='Sales')
plt.title('Sales Outliers')
# Out:
# Text(0.5, 1.0, 'Sales Outliers')

# %%
plt.subplot(1,2,1)
sns.boxplot(data=data,y='Profit')
plt.title('Profit Outliers')
# Out:
# Text(0.5, 1.0, 'Profit Outliers')

# %%
## Observation:
# from the both  boxplot, we can see that both sales and profit columns and sales columns contain several outliers.
# Most of the data is concentrated near lower values, and few high values are stretching the scale.
# these outliers may affect analusis, so they should ve treated or checked carefully.

# %%
import matplotlib.pyplot as plt
import seaborn as sns 
sns.histplot(data['Sales'],bins=30)
plt.title('Sales Distribution')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns 
sns.histplot(data['Profit'],bins=30)
plt.title('Profit Distribution')
plt.show()

# %% [markdown]
# ### we check correlation check:

# %%
data.corr(numeric_only=True)
sns.heatmap(data.corr(numeric_only=True),annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %%
sns.barplot(x='Category',y='Sales',data=data)
plt.title('sales by Category')
plt.show()

# %%
sns.barplot(x='Region',y='Profit',data=data)
plt.title('Profit by Category')
plt.show()

# %%
sns.barplot(x='Category',y='Sales',data=data,estimator='sum')
plt.title('Total Sales by Category')
plt.show()

# %%
sns.barplot(x='Region',y='Profit',data=data,estimator='sum')
plt.title('Total Profit by Region')
plt.show()

# %%
sns.scatterplot(x='Sales',y='Profit',data=data)
plt.title('Sales vs Profit')
plt.show()

# %%
sns.pairplot(data[['Sales','Profit','Quantity']])

# %% [markdown]
# ## Final Summary:
# the dataset contains sales information of a superstore with 21 columns and 9994 rows and no missing values.
# Both Sales and Profit columns contain requirement .
# Technology category shows the hightest total sales and profit.
# Some regions like West perform vetter.while others have lower profit.
# There is a positive relationship between Sales and profit.
# Overall , the data is clean and ready for further analysis or model building.

# %% [markdown]
# # Business insights
# Technology category gives highest profit. so the company should promote and stock more of these items.
# Discounts reduce profit; controlling them can improve earnings.
# some regions show low profit despite good sales, meaning cost or procing issues these need adjustment.
# Focus marketing and delivery in West or East regions where profits are higher.
